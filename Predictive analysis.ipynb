# %%
import datetime
import csv
import json

# %%
degradation_coefficient_low = 1.06
degradation_coefficient_high = 1.1
max_score = 3

# %%
def get_file(file):
    reader = csv.DictReader(open(file, 'r'))
    data = []
    for row in reader:
        for key, value in row.items():
            if key in ['distance', 'hr', 'elevation']:
                row[key] = float(row[key])
        data.append(row)

    return data

def json_data(file, data):
    with open(file, 'w') as fp:
        json.dump(data, fp)

def multiply_n(number, n):
    result = 1
    for i in range(0, n):
        result *= number

    return result

def time_to_seconds(time):
    result = 0
    time_list = time.split(':')

    for k, item in enumerate(reversed(time_list)):
        result += float(item) * multiply_n(60, k)

    return result

def seconds_to_time(number_of_seconds):
    result = str(datetime.timedelta(seconds=number_of_seconds))
    return result

def get_pace(distance, time):
    pace = (time / distance)
    return pace

def get_time_by_pace(distance, pace):
    time = (distance * pace)
    return time

# ------------------------ [ main functions ] ---------------------------------

def linear(desired_distance, pace):
    #linear time distance km and pace 
    predicted_time = get_time_by_pace(desired_distance, time_to_seconds(pace))

    return predicted_time

def riegel(desired_distance, distance, pace, degradation_coefficient):
    # T2 = T1 * (D2 / D1)^C
    time_seconds = get_time_by_pace(distance, time_to_seconds(pace))
    predicted_time = time_seconds * ( desired_distance / distance ) ** degradation_coefficient

    return predicted_time

def get_coefficient_by_hr(hr):
    return 1

def get_coefficient_by_score(score):
    # 3% should be the highest coefficient
    # 0% should be the lowest coefficient

    # 3 = 100% of the (high-low)
    # N = X%
    # X% = (N / 3) * 100
    coefficient_ratio = score / max_score
    coefficient_increase = (degradation_coefficient_high - degradation_coefficient_low) * coefficient_ratio

    degradation_coefficient = degradation_coefficient_low + coefficient_increase

    return degradation_coefficient

def get_score(distance, elevation):
    # score = elevation(m) / distance(m) * 100
    score = (elevation / (distance * 1000)) * 100

    return score

def calculate(distance, elevation):
    prediction_data = []

    degradation_coefficient = get_coefficient_by_score(get_score(distance, elevation))

    data = get_file('data.csv')

    for num, run in enumerate(data):
        print( "Run log number %s" % (num+1))

        LP = linear(distance, run['pace'])
        PH = riegel(distance, run['distance'], run['gap'], degradation_coefficient_high)
        PM = riegel(distance, run['distance'], run['gap'], degradation_coefficient)
        LG = linear(distance, run['pace'])
        PL = riegel(distance, run['distance'], run['gap'], degradation_coefficient_low)

        prediction_data_value = {
            'LP': {'time': seconds_to_time(LP)},'PH': {'time': seconds_to_time(PH)},'PM': {'time': seconds_to_time(PM)},
            'LG': {'time': seconds_to_time(LG)},'PL': {'time': seconds_to_time(PL)},}
        prediction_data.append(prediction_data_value)

        print ("Top limit","\n","Linear pace prediction: %s" % prediction_data_value['LP']['time'],
              "\n", "Pete Reigel with a high GAP prediction: %s" % prediction_data_value['PH']['time'])
        print ("Middle limit","\n","Pete Reigel with a medium GAP prediction: %s" % 
               prediction_data_value['PM']['time'])
        print ("Low limit","\n","Linear GAP prediction: %s" % prediction_data_value['LG']['time'],"\n",
               "Pete Reigel with a low GAP prediction: %s" % prediction_data_value['PL']['time'],"\n")

        json_data('output.json', prediction_data)
        
#42.195 km  = 26.2 miles (Marathon)
calculate(42.195, 82)
# Out:
# Run log number 1
# Top limit
#  Linear pace prediction: 6:04:17.010000
#  Pete Reigel with a high GAP prediction: 4:01:43.156436
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:32:12.857185
# Low limit
#  Linear GAP prediction: 6:04:17.010000
#  Pete Reigel with a low GAP prediction: 3:30:18.560837
#
# Run log number 2
# Top limit
#  Linear pace prediction: 5:24:54.090000
#  Pete Reigel with a high GAP prediction: 1:38:25.216916
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:26:02.356598
# Low limit
#  Linear GAP prediction: 5:24:54.090000
#  Pete Reigel with a low GAP prediction: 1:25:14.506502
#
# Run log number 3
# Top limit
#  Linear pace prediction: 6:09:54.570000
#  Pete Reigel with a high GAP prediction: 0:03:40.626387
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:11.875691
# Low limit
#  Linear GAP prediction: 6:09:54.570000
#  Pete Reigel with a low GAP prediction: 0:03:10.028994
#
# Run log number 4
# Top limit
#  Linear pace prediction: 5:50:55.305000
#  Pete Reigel with a high GAP prediction: 0:01:02.961748
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:00:56.174448
# Low limit
#  Linear GAP prediction: 5:50:55.305000
#  Pete Reigel with a low GAP prediction: 0:00:55.732373
#
# Run log number 5
# Top limit
#  Linear pace prediction: 5:32:38.235000
#  Pete Reigel with a high GAP prediction: 0:05:00.297027
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:04:21.164135
# Low limit
#  Linear GAP prediction: 5:32:38.235000
#  Pete Reigel with a low GAP prediction: 0:04:18.650575
#
# Run log number 6
# Top limit
#  Linear pace prediction: 5:55:50.670000
#  Pete Reigel with a high GAP prediction: 2:55:00.080334
# Middle limit
#  Pete Reigel with a medium GAP prediction: 2:39:17.035508
# Low limit
#  Linear GAP prediction: 5:55:50.670000
#  Pete Reigel with a low GAP prediction: 2:38:14.942899
#
# Run log number 7
# Top limit
#  Linear pace prediction: 6:45:46.515000
#  Pete Reigel with a high GAP prediction: 0:26:59.026361
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:24:04.764240
# Low limit
#  Linear GAP prediction: 6:45:46.515000
#  Pete Reigel with a low GAP prediction: 0:23:53.412947
#
# Run log number 8
# Top limit
#  Linear pace prediction: 6:40:51.150000
#  Pete Reigel with a high GAP prediction: 4:07:34.270829
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:37:05.875748
# Low limit
#  Linear GAP prediction: 6:40:51.150000
#  Pete Reigel with a low GAP prediction: 3:35:07.903800
#
# Run log number 9
# Top limit
#  Linear pace prediction: 5:49:30.915000
#  Pete Reigel with a high GAP prediction: 0:06:19.122476
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:05:43.465407
# Low limit
#  Linear GAP prediction: 5:49:30.915000
#  Pete Reigel with a low GAP prediction: 0:05:41.123589
#
# Run log number 10
# Top limit
#  Linear pace prediction: 6:12:01.155000
#  Pete Reigel with a high GAP prediction: 0:01:39.230160
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:01:31.620405
# Low limit
#  Linear GAP prediction: 6:12:01.155000
#  Pete Reigel with a low GAP prediction: 0:01:31.115456
#
# Run log number 11
# Top limit
#  Linear pace prediction: 10:25:11.355000
#  Pete Reigel with a high GAP prediction: 4:25:36.200705
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:45:47.928693
# Low limit
#  Linear GAP prediction: 10:25:11.355000
#  Pete Reigel with a low GAP prediction: 3:43:16.423200
#
# Run log number 12
# Top limit
#  Linear pace prediction: 5:57:15.060000
#  Pete Reigel with a high GAP prediction: 0:06:23.303061
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:05:42.046658
# Low limit
#  Linear GAP prediction: 5:57:15.060000
#  Pete Reigel with a low GAP prediction: 0:05:39.359249
#
# Run log number 13
# Top limit
#  Linear pace prediction: 6:07:47.985000
#  Pete Reigel with a high GAP prediction: 0:46:20.944257
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:41:25.246301
# Low limit
#  Linear GAP prediction: 6:07:47.985000
#  Pete Reigel with a low GAP prediction: 0:41:05.969470
#
# Run log number 14
# Top limit
#  Linear pace prediction: 5:53:01.890000
#  Pete Reigel with a high GAP prediction: 0:03:37.395766
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:13.996612
# Low limit
#  Linear GAP prediction: 5:53:01.890000
#  Pete Reigel with a low GAP prediction: 0:03:12.472410
#
# Run log number 15
# Top limit
#  Linear pace prediction: 5:40:22.380000
#  Pete Reigel with a high GAP prediction: 0:10:47.925145
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:09:47.132200
# Low limit
#  Linear GAP prediction: 5:40:22.380000
#  Pete Reigel with a low GAP prediction: 0:09:43.139017
#
# Run log number 16
# Top limit
#  Linear pace prediction: 6:45:46.515000
#  Pete Reigel with a high GAP prediction: 7:32:28.592643
# Middle limit
#  Pete Reigel with a medium GAP prediction: 6:42:11.683896
# Low limit
#  Linear GAP prediction: 6:45:46.515000
#  Pete Reigel with a low GAP prediction: 6:38:55.583792
#
# Run log number 17
# Top limit
#  Linear pace prediction: 6:05:41.400000
#  Pete Reigel with a high GAP prediction: 0:25:48.969063
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:23:50.925855
# Low limit
#  Linear GAP prediction: 6:05:41.400000
#  Pete Reigel with a low GAP prediction: 0:23:43.090837
#
# Run log number 18
# Top limit
#  Linear pace prediction: 5:39:40.185000
#  Pete Reigel with a high GAP prediction: 0:38:25.067516
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:33:30.409737
# Low limit
#  Linear GAP prediction: 5:39:40.185000
#  Pete Reigel with a low GAP prediction: 0:33:11.453961
#
# Run log number 19
# Top limit
#  Linear pace prediction: 6:10:36.765000
#  Pete Reigel with a high GAP prediction: 0:00:00
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:00:00
# Low limit
#  Linear GAP prediction: 6:10:36.765000
#  Pete Reigel with a low GAP prediction: 0:00:00
#
# Run log number 20
# Top limit
#  Linear pace prediction: 5:50:55.305000
#  Pete Reigel with a high GAP prediction: 0:12:32.004257
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:11:21.529868
# Low limit
#  Linear GAP prediction: 5:50:55.305000
#  Pete Reigel with a low GAP prediction: 0:11:16.900450
#
# Run log number 21
# Top limit
#  Linear pace prediction: 5:53:44.085000
#  Pete Reigel with a high GAP prediction: 0:04:43.987153
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:04:26.872239
# Low limit
#  Linear GAP prediction: 5:53:44.085000
#  Pete Reigel with a low GAP prediction: 0:04:25.725697
#
# Run log number 22
# Top limit
#  Linear pace prediction: 5:15:03.360000
#  Pete Reigel with a high GAP prediction: 0:15:00.506134
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:13:36.014244
# Low limit
#  Linear GAP prediction: 5:15:03.360000
#  Pete Reigel with a low GAP prediction: 0:13:30.464396
#
# Run log number 23
# Top limit
#  Linear pace prediction: 6:16:56.520000
#  Pete Reigel with a high GAP prediction: 0:21:15.107660
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:19:27.970124
# Low limit
#  Linear GAP prediction: 6:16:56.520000
#  Pete Reigel with a low GAP prediction: 0:19:20.891603
#
# Run log number 24
# Top limit
#  Linear pace prediction: 5:30:31.650000
#  Pete Reigel with a high GAP prediction: 0:58:48.066710
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:53:19.771111
# Low limit
#  Linear GAP prediction: 5:30:31.650000
#  Pete Reigel with a low GAP prediction: 0:52:58.197022
#
# Run log number 25
# Top limit
#  Linear pace prediction: 6:31:00.420000
#  Pete Reigel with a high GAP prediction: 4:33:30.357583
# Middle limit
#  Pete Reigel with a medium GAP prediction: 4:01:17.320418
# Low limit
#  Linear GAP prediction: 6:31:00.420000
#  Pete Reigel with a low GAP prediction: 3:59:12.186640
#
# Run log number 26
# Top limit
#  Linear pace prediction: 6:15:32.130000
#  Pete Reigel with a high GAP prediction: 0:00:00
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:00:00
# Low limit
#  Linear GAP prediction: 6:15:32.130000
#  Pete Reigel with a low GAP prediction: 0:00:00
#
# Run log number 27
# Top limit
#  Linear pace prediction: 5:51:37.500000
#  Pete Reigel with a high GAP prediction: 0:11:26.361383
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:10:21.962076
# Low limit
#  Linear GAP prediction: 5:51:37.500000
#  Pete Reigel with a low GAP prediction: 0:10:17.732009
#
# Run log number 28
# Top limit
#  Linear pace prediction: 5:11:32.385000
#  Pete Reigel with a high GAP prediction: 1:51:45.910593
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:41:34.763460
# Low limit
#  Linear GAP prediction: 5:11:32.385000
#  Pete Reigel with a low GAP prediction: 1:40:54.555617
#
# Run log number 29
# Top limit
#  Linear pace prediction: 6:26:05.055000
#  Pete Reigel with a high GAP prediction: 0:03:40.626387
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:11.875691
# Low limit
#  Linear GAP prediction: 6:26:05.055000
#  Pete Reigel with a low GAP prediction: 0:03:10.028994
#
# Run log number 30
# Top limit
#  Linear pace prediction: 5:55:08.475000
#  Pete Reigel with a high GAP prediction: 0:08:27.219870
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:07:44.472542
# Low limit
#  Linear GAP prediction: 5:55:08.475000
#  Pete Reigel with a low GAP prediction: 0:07:41.648675
#
# Run log number 31
# Top limit
#  Linear pace prediction: 5:48:48.720000
#  Pete Reigel with a high GAP prediction: 0:06:57.628708
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:06:12.677702
# Low limit
#  Linear GAP prediction: 5:48:48.720000
#  Pete Reigel with a low GAP prediction: 0:06:09.749629
#
# Run log number 32
# Top limit
#  Linear pace prediction: 6:00:03.840000
#  Pete Reigel with a high GAP prediction: 0:12:12.978771
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:11:21.526929
# Low limit
#  Linear GAP prediction: 6:00:03.840000
#  Pete Reigel with a low GAP prediction: 0:11:18.099852
#
# Run log number 33
# Top limit
#  Linear pace prediction: 6:00:46.035000
#  Pete Reigel with a high GAP prediction: 0:04:02.357535
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:46.618163
# Low limit
#  Linear GAP prediction: 6:00:46.035000
#  Pete Reigel with a low GAP prediction: 0:03:45.566607
#
# Run log number 34
# Top limit
#  Linear pace prediction: 5:54:26.280000
#  Pete Reigel with a high GAP prediction: 0:05:40.660775
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:05:08.621090
# Low limit
#  Linear GAP prediction: 5:54:26.280000
#  Pete Reigel with a low GAP prediction: 0:05:06.516848
#
# Run log number 35
# Top limit
#  Linear pace prediction: 5:07:19.215000
#  Pete Reigel with a high GAP prediction: 2:49:51.342406
# Middle limit
#  Pete Reigel with a medium GAP prediction: 2:34:33.985302
# Low limit
#  Linear GAP prediction: 5:07:19.215000
#  Pete Reigel with a low GAP prediction: 2:33:33.591251
#
# Run log number 36
# Top limit
#  Linear pace prediction: 6:16:14.325000
#  Pete Reigel with a high GAP prediction: 0:02:29.496383
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:02:16.897170
# Low limit
#  Linear GAP prediction: 6:16:14.325000
#  Pete Reigel with a low GAP prediction: 0:02:16.064873
#
# Run log number 37
# Top limit
#  Linear pace prediction: 6:28:53.835000
#  Pete Reigel with a high GAP prediction: 0:04:05.384475
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:33.328032
# Low limit
#  Linear GAP prediction: 6:28:53.835000
#  Pete Reigel with a low GAP prediction: 0:03:31.269421
#
# Run log number 38
# Top limit
#  Linear pace prediction: 6:21:09.690000
#  Pete Reigel with a high GAP prediction: 2:12:06.745237
# Middle limit
#  Pete Reigel with a medium GAP prediction: 2:01:15.776199
# Low limit
#  Linear GAP prediction: 6:21:09.690000
#  Pete Reigel with a low GAP prediction: 2:00:32.718719
#
# Run log number 39
# Top limit
#  Linear pace prediction: 5:43:11.160000
#  Pete Reigel with a high GAP prediction: 0:07:02.867242
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:06:07.761742
# Low limit
#  Linear GAP prediction: 5:43:11.160000
#  Pete Reigel with a low GAP prediction: 0:06:04.222238
#
# Run log number 40
# Top limit
#  Linear pace prediction: 6:11:18.960000
#  Pete Reigel with a high GAP prediction: 1:54:58.679901
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:43:01.149074
# Low limit
#  Linear GAP prediction: 6:11:18.960000
#  Pete Reigel with a low GAP prediction: 1:42:14.306550
#
# Run log number 41
# Top limit
#  Linear pace prediction: 5:57:57.255000
#  Pete Reigel with a high GAP prediction: 0:04:17.397452
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:43.854973
# Low limit
#  Linear GAP prediction: 5:57:57.255000
#  Pete Reigel with a low GAP prediction: 0:03:41.700493
#
# Run log number 42
# Top limit
#  Linear pace prediction: 5:39:40.185000
#  Pete Reigel with a high GAP prediction: 0:00:00
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:00:00
# Low limit
#  Linear GAP prediction: 5:39:40.185000
#  Pete Reigel with a low GAP prediction: 0:00:00
#
# Run log number 43
# Top limit
#  Linear pace prediction: 5:51:37.500000
#  Pete Reigel with a high GAP prediction: 0:04:17.442354
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:49.732830
# Low limit
#  Linear GAP prediction: 5:51:37.500000
#  Pete Reigel with a low GAP prediction: 0:03:47.927854
#
# Run log number 44
# Top limit
#  Linear pace prediction: 5:56:32.865000
#  Pete Reigel with a high GAP prediction: 0:02:50.387079
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:02:34.342690
# Low limit
#  Linear GAP prediction: 5:56:32.865000
#  Pete Reigel with a low GAP prediction: 0:02:33.289028
#
# Run log number 45
# Top limit
#  Linear pace prediction: 5:47:24.330000
#  Pete Reigel with a high GAP prediction: 0:04:11.268941
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:38.525093
# Low limit
#  Linear GAP prediction: 5:47:24.330000
#  Pete Reigel with a low GAP prediction: 0:03:36.421910
#
# Run log number 46
# Top limit
#  Linear pace prediction: 5:31:56.040000
#  Pete Reigel with a high GAP prediction: 0:00:00
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:00:00
# Low limit
#  Linear GAP prediction: 5:31:56.040000
#  Pete Reigel with a low GAP prediction: 0:00:00
#
# Run log number 47
# Top limit
#  Linear pace prediction: 6:12:01.155000
#  Pete Reigel with a high GAP prediction: 0:02:11.647291
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:01:57.455663
# Low limit
#  Linear GAP prediction: 6:12:01.155000
#  Pete Reigel with a low GAP prediction: 0:01:56.531326
#
# Run log number 48
# Top limit
#  Linear pace prediction: 5:11:32.385000
#  Pete Reigel with a high GAP prediction: 4:28:28.685546
# Middle limit
#  Pete Reigel with a medium GAP prediction: 4:10:37.078364
# Low limit
#  Linear GAP prediction: 5:11:32.385000
#  Pete Reigel with a low GAP prediction: 4:09:25.549105
#
# Run log number 49
# Top limit
#  Linear pace prediction: 5:21:23.115000
#  Pete Reigel with a high GAP prediction: 1:19:52.911256
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:11:30.776157
# Low limit
#  Linear GAP prediction: 5:21:23.115000
#  Pete Reigel with a low GAP prediction: 1:10:58.010350
#
# Run log number 50
# Top limit
#  Linear pace prediction: 5:53:44.085000
#  Pete Reigel with a high GAP prediction: 4:59:24.136249
# Middle limit
#  Pete Reigel with a medium GAP prediction: 4:47:04.804533
# Low limit
#  Linear GAP prediction: 5:53:44.085000
#  Pete Reigel with a low GAP prediction: 4:46:14.735805
#
# Run log number 51
# Top limit
#  Linear pace prediction: 5:48:06.525000
#  Pete Reigel with a high GAP prediction: 0:05:15.010235
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:04:48.461895
# Low limit
#  Linear GAP prediction: 5:48:06.525000
#  Pete Reigel with a low GAP prediction: 0:04:46.708125
#
# Run log number 52
# Top limit
#  Linear pace prediction: 5:36:09.210000
#  Pete Reigel with a high GAP prediction: 0:00:00
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:00:00
# Low limit
#  Linear GAP prediction: 5:36:09.210000
#  Pete Reigel with a low GAP prediction: 0:00:00
#
# Run log number 53
# Top limit
#  Linear pace prediction: 5:36:51.405000
#  Pete Reigel with a high GAP prediction: 0:05:18.682661
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:04:48.710052
# Low limit
#  Linear GAP prediction: 5:36:51.405000
#  Pete Reigel with a low GAP prediction: 0:04:46.741567
#
# Run log number 54
# Top limit
#  Linear pace prediction: 5:55:08.475000
#  Pete Reigel with a high GAP prediction: 0:04:02.357535
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:46.618163
# Low limit
#  Linear GAP prediction: 5:55:08.475000
#  Pete Reigel with a low GAP prediction: 0:03:45.566607
#
# Run log number 55
# Top limit
#  Linear pace prediction: 6:04:17.010000
#  Pete Reigel with a high GAP prediction: 0:04:23.110053
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:04:09.323596
# Low limit
#  Linear GAP prediction: 6:04:17.010000
#  Pete Reigel with a low GAP prediction: 0:04:08.395867
#
# Run log number 56
# Top limit
#  Linear pace prediction: 5:53:44.085000
#  Pete Reigel with a high GAP prediction: 0:04:16.279513
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:54.680863
# Low limit
#  Linear GAP prediction: 5:53:44.085000
#  Pete Reigel with a low GAP prediction: 0:03:53.254067
#
# Run log number 57
# Top limit
#  Linear pace prediction: 5:52:19.695000
#  Pete Reigel with a high GAP prediction: 0:02:06.227883
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:01:58.030293
# Low limit
#  Linear GAP prediction: 5:52:19.695000
#  Pete Reigel with a low GAP prediction: 0:01:57.482608
#
# Run log number 58
# Top limit
#  Linear pace prediction: 5:53:01.890000
#  Pete Reigel with a high GAP prediction: 0:08:37.769208
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:07:54.176985
# Low limit
#  Linear GAP prediction: 5:53:01.890000
#  Pete Reigel with a low GAP prediction: 0:07:51.297159
#
# Run log number 59
# Top limit
#  Linear pace prediction: 5:27:00.675000
#  Pete Reigel with a high GAP prediction: 0:08:59.120516
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:08:13.730675
# Low limit
#  Linear GAP prediction: 5:27:00.675000
#  Pete Reigel with a low GAP prediction: 0:08:10.732093
#
# Run log number 60
# Top limit
#  Linear pace prediction: 5:24:54.090000
#  Pete Reigel with a high GAP prediction: 1:53:02.373021
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:44:33.687082
# Low limit
#  Linear GAP prediction: 5:24:54.090000
#  Pete Reigel with a low GAP prediction: 1:43:59.899632
#
# Run log number 61
# Top limit
#  Linear pace prediction: 5:24:11.895000
#  Pete Reigel with a high GAP prediction: 1:09:44.505996
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:03:57.801732
# Low limit
#  Linear GAP prediction: 5:24:11.895000
#  Pete Reigel with a low GAP prediction: 1:03:34.879339
#
# Run log number 62
# Top limit
#  Linear pace prediction: 6:12:01.155000
#  Pete Reigel with a high GAP prediction: 6:46:41.621475
# Middle limit
#  Pete Reigel with a medium GAP prediction: 6:11:11.170531
# Low limit
#  Linear GAP prediction: 6:12:01.155000
#  Pete Reigel with a low GAP prediction: 6:08:50.686642
#
# Run log number 63
# Top limit
#  Linear pace prediction: 6:12:43.350000
#  Pete Reigel with a high GAP prediction: 2:54:17.941576
# Middle limit
#  Pete Reigel with a medium GAP prediction: 2:44:34.695182
# Low limit
#  Linear GAP prediction: 6:12:43.350000
#  Pete Reigel with a low GAP prediction: 2:43:55.522299
#
# Run log number 64
# Top limit
#  Linear pace prediction: 7:03:21.390000
#  Pete Reigel with a high GAP prediction: 4:10:48.761366
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:44:54.681387
# Low limit
#  Linear GAP prediction: 7:03:21.390000
#  Pete Reigel with a low GAP prediction: 3:43:13.180909
#
# Run log number 65
# Top limit
#  Linear pace prediction: 5:52:19.695000
#  Pete Reigel with a high GAP prediction: 6:16:49.104138
# Middle limit
#  Pete Reigel with a medium GAP prediction: 5:47:29.876249
# Low limit
#  Linear GAP prediction: 5:52:19.695000
#  Pete Reigel with a low GAP prediction: 5:45:33.218713
#
# Run log number 66
# Top limit
#  Linear pace prediction: 6:02:10.425000
#  Pete Reigel with a high GAP prediction: 6:48:24.851220
# Middle limit
#  Pete Reigel with a medium GAP prediction: 6:15:45.941175
# Low limit
#  Linear GAP prediction: 6:02:10.425000
#  Pete Reigel with a low GAP prediction: 6:13:36.204826
#
# Run log number 67
# Top limit
#  Linear pace prediction: 5:57:15.060000
#  Pete Reigel with a high GAP prediction: 1:16:15.485369
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:06:39.901684
# Low limit
#  Linear GAP prediction: 5:57:15.060000
#  Pete Reigel with a low GAP prediction: 1:06:02.826430
#
# Run log number 68
# Top limit
#  Linear pace prediction: 5:57:15.060000
#  Pete Reigel with a high GAP prediction: 0:14:40.776786
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:12:46.561374
# Low limit
#  Linear GAP prediction: 5:57:15.060000
#  Pete Reigel with a low GAP prediction: 0:12:39.222219
#
# Run log number 69
# Top limit
#  Linear pace prediction: 6:11:18.960000
#  Pete Reigel with a high GAP prediction: 1:48:57.707326
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:35:27.822723
# Low limit
#  Linear GAP prediction: 6:11:18.960000
#  Pete Reigel with a low GAP prediction: 1:34:35.592934
#
# Run log number 70
# Top limit
#  Linear pace prediction: 5:31:13.845000
#  Pete Reigel with a high GAP prediction: 0:10:22.259790
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:09:58.674086
# Low limit
#  Linear GAP prediction: 5:31:13.845000
#  Pete Reigel with a low GAP prediction: 0:09:57.073912
#
# Run log number 71
# Top limit
#  Linear pace prediction: 5:25:36.285000
#  Pete Reigel with a high GAP prediction: 1:56:20.297782
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:46:45.928797
# Low limit
#  Linear GAP prediction: 5:25:36.285000
#  Pete Reigel with a low GAP prediction: 1:46:07.941539
#
# Run log number 72
# Top limit
#  Linear pace prediction: 5:49:30.915000
#  Pete Reigel with a high GAP prediction: 0:06:44.481710
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:05:51.772101
# Low limit
#  Linear GAP prediction: 5:49:30.915000
#  Pete Reigel with a low GAP prediction: 0:05:48.386489
#
# Run log number 73
# Top limit
#  Linear pace prediction: 5:40:22.380000
#  Pete Reigel with a high GAP prediction: 0:06:40.436739
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:06:06.688849
# Low limit
#  Linear GAP prediction: 5:40:22.380000
#  Pete Reigel with a low GAP prediction: 0:06:04.459480
#
# Run log number 74
# Top limit
#  Linear pace prediction: 5:49:30.915000
#  Pete Reigel with a high GAP prediction: 0:06:37.960923
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:05:46.228647
# Low limit
#  Linear GAP prediction: 5:49:30.915000
#  Pete Reigel with a low GAP prediction: 0:05:42.905142
#
# Run log number 75
# Top limit
#  Linear pace prediction: 6:08:30.180000
#  Pete Reigel with a high GAP prediction: 0:04:26.957826
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:04:04.459233
# Low limit
#  Linear GAP prediction: 6:08:30.180000
#  Pete Reigel with a low GAP prediction: 0:04:02.972987
#
# Run log number 76
# Top limit
#  Linear pace prediction: 6:12:01.155000
#  Pete Reigel with a high GAP prediction: 6:16:05.862238
# Middle limit
#  Pete Reigel with a medium GAP prediction: 5:59:53.553883
# Low limit
#  Linear GAP prediction: 6:12:01.155000
#  Pete Reigel with a low GAP prediction: 5:58:47.779027
#
# Run log number 77
# Top limit
#  Linear pace prediction: 6:09:54.570000
#  Pete Reigel with a high GAP prediction: 2:55:45.079952
# Middle limit
#  Pete Reigel with a medium GAP prediction: 2:34:28.417062
# Low limit
#  Linear GAP prediction: 6:09:54.570000
#  Pete Reigel with a low GAP prediction: 2:33:05.940524
#
# Run log number 78
# Top limit
#  Linear pace prediction: 5:51:37.500000
#  Pete Reigel with a high GAP prediction: 0:14:16.862219
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:12:56.369295
# Low limit
#  Linear GAP prediction: 5:51:37.500000
#  Pete Reigel with a low GAP prediction: 0:12:51.082475
#
# Run log number 79
# Top limit
#  Linear pace prediction: 5:46:42.135000
#  Pete Reigel with a high GAP prediction: 0:06:23.583907
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:06:00.483469
# Low limit
#  Linear GAP prediction: 5:46:42.135000
#  Pete Reigel with a low GAP prediction: 0:05:58.935913
#
# Run log number 80
# Top limit
#  Linear pace prediction: 5:48:06.525000
#  Pete Reigel with a high GAP prediction: 0:31:34.308298
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:29:09.559152
# Low limit
#  Linear GAP prediction: 5:48:06.525000
#  Pete Reigel with a low GAP prediction: 0:28:59.952705
#
# Run log number 81
# Top limit
#  Linear pace prediction: 5:55:50.670000
#  Pete Reigel with a high GAP prediction: 0:22:14.309453
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:21:13.237363
# Low limit
#  Linear GAP prediction: 5:55:50.670000
#  Pete Reigel with a low GAP prediction: 0:21:09.112190
#
# Run log number 82
# Top limit
#  Linear pace prediction: 5:33:20.430000
#  Pete Reigel with a high GAP prediction: 0:02:50.387079
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:02:34.342690
# Low limit
#  Linear GAP prediction: 5:33:20.430000
#  Pete Reigel with a low GAP prediction: 0:02:33.289028
#
# Run log number 83
# Top limit
#  Linear pace prediction: 5:06:37.020000
#  Pete Reigel with a high GAP prediction: 3:20:11.407904
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:05:33.658871
# Low limit
#  Linear GAP prediction: 5:06:37.020000
#  Pete Reigel with a low GAP prediction: 3:04:35.292260
#
# Run log number 84
# Top limit
#  Linear pace prediction: 5:38:15.795000
#  Pete Reigel with a high GAP prediction: 0:03:12.034482
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:01.257183
# Low limit
#  Linear GAP prediction: 5:38:15.795000
#  Pete Reigel with a low GAP prediction: 0:03:00.533487
#
# Run log number 85
# Top limit
#  Linear pace prediction: 5:10:50.190000
#  Pete Reigel with a high GAP prediction: 1:58:41.040247
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:47:53.532007
# Low limit
#  Linear GAP prediction: 5:10:50.190000
#  Pete Reigel with a low GAP prediction: 1:47:10.926682
#
# Run log number 86
# Top limit
#  Linear pace prediction: 5:59:21.645000
#  Pete Reigel with a high GAP prediction: 0:03:12.967873
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:06.918887
# Low limit
#  Linear GAP prediction: 5:59:21.645000
#  Pete Reigel with a low GAP prediction: 0:03:06.506992
#
# Run log number 87
# Top limit
#  Linear pace prediction: 5:19:16.530000
#  Pete Reigel with a high GAP prediction: 0:24:37.350442
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:21:26.699227
# Low limit
#  Linear GAP prediction: 5:19:16.530000
#  Pete Reigel with a low GAP prediction: 0:21:14.443712
#
# Run log number 88
# Top limit
#  Linear pace prediction: 5:20:40.920000
#  Pete Reigel with a high GAP prediction: 1:13:07.932353
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:06:23.419026
# Low limit
#  Linear GAP prediction: 5:20:40.920000
#  Pete Reigel with a low GAP prediction: 1:05:56.822502
#
# Run log number 89
# Top limit
#  Linear pace prediction: 5:22:05.310000
#  Pete Reigel with a high GAP prediction: 1:53:15.145627
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:42:55.160605
# Low limit
#  Linear GAP prediction: 5:22:05.310000
#  Pete Reigel with a low GAP prediction: 1:42:14.373838
#
# Run log number 90
# Top limit
#  Linear pace prediction: 7:37:48.945000
#  Pete Reigel with a high GAP prediction: 4:50:01.333436
# Middle limit
#  Pete Reigel with a medium GAP prediction: 4:14:58.857945
# Low limit
#  Linear GAP prediction: 7:37:48.945000
#  Pete Reigel with a low GAP prediction: 4:12:43.010648
#
# Run log number 91
# Top limit
#  Linear pace prediction: 5:37:33.600000
#  Pete Reigel with a high GAP prediction: 2:04:42.099584
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:55:23.387853
# Low limit
#  Linear GAP prediction: 5:37:33.600000
#  Pete Reigel with a low GAP prediction: 1:54:46.270517
#
# Run log number 92
# Top limit
#  Linear pace prediction: 6:04:17.010000
#  Pete Reigel with a high GAP prediction: 0:00:00
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:00:00
# Low limit
#  Linear GAP prediction: 6:04:17.010000
#  Pete Reigel with a low GAP prediction: 0:00:00
#
# Run log number 93
# Top limit
#  Linear pace prediction: 5:57:57.255000
#  Pete Reigel with a high GAP prediction: 0:05:01.524948
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:04:49.341705
# Low limit
#  Linear GAP prediction: 5:57:57.255000
#  Pete Reigel with a low GAP prediction: 0:04:48.516288
#
# Run log number 94
# Top limit
#  Linear pace prediction: 9:39:28.680000
#  Pete Reigel with a high GAP prediction: 0:00:00
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:00:00
# Low limit
#  Linear GAP prediction: 9:39:28.680000
#  Pete Reigel with a low GAP prediction: 0:00:00
#
# Run log number 95
# Top limit
#  Linear pace prediction: 5:19:58.725000
#  Pete Reigel with a high GAP prediction: 3:14:38.736721
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:00:22.369244
# Low limit
#  Linear GAP prediction: 5:19:58.725000
#  Pete Reigel with a low GAP prediction: 2:59:25.432751
#
# Run log number 96
# Top limit
#  Linear pace prediction: 5:21:23.115000
#  Pete Reigel with a high GAP prediction: 1:03:04.727293
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:59:48.543064
# Low limit
#  Linear GAP prediction: 5:21:23.115000
#  Pete Reigel with a low GAP prediction: 0:59:35.337059
#
# Run log number 97
# Top limit
#  Linear pace prediction: 6:18:20.910000
#  Pete Reigel with a high GAP prediction: 2:09:17.518527
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:53:16.524940
# Low limit
#  Linear GAP prediction: 6:18:20.910000
#  Pete Reigel with a low GAP prediction: 1:52:14.550072
#
# Run log number 98
# Top limit
#  Linear pace prediction: 5:33:20.430000
#  Pete Reigel with a high GAP prediction: 0:05:09.136009
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:05:00.633050
# Low limit
#  Linear GAP prediction: 5:33:20.430000
#  Pete Reigel with a low GAP prediction: 0:05:00.052824
#
# Run log number 99
# Top limit
#  Linear pace prediction: 5:21:23.115000
#  Pete Reigel with a high GAP prediction: 2:38:59.402034
# Middle limit
#  Pete Reigel with a medium GAP prediction: 2:27:13.850987
# Low limit
#  Linear GAP prediction: 5:21:23.115000
#  Pete Reigel with a low GAP prediction: 2:26:26.959067
#
# Run log number 100
# Top limit
#  Linear pace prediction: 5:24:54.090000
#  Pete Reigel with a high GAP prediction: 4:49:59.883281
# Middle limit
#  Pete Reigel with a medium GAP prediction: 4:16:52.851945
# Low limit
#  Linear GAP prediction: 5:24:54.090000
#  Pete Reigel with a low GAP prediction: 4:14:43.937503
#
# Run log number 101
# Top limit
#  Linear pace prediction: 5:31:56.040000
#  Pete Reigel with a high GAP prediction: 3:41:24.097791
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:28:36.200903
# Low limit
#  Linear GAP prediction: 5:31:56.040000
#  Pete Reigel with a low GAP prediction: 3:27:44.686238
#
# Run log number 102
# Top limit
#  Linear pace prediction: 5:22:05.310000
#  Pete Reigel with a high GAP prediction: 2:11:46.923533
# Middle limit
#  Pete Reigel with a medium GAP prediction: 2:01:00.743666
# Low limit
#  Linear GAP prediction: 5:22:05.310000
#  Pete Reigel with a low GAP prediction: 2:00:17.992875
#
# Run log number 103
# Top limit
#  Linear pace prediction: 5:33:20.430000
#  Pete Reigel with a high GAP prediction: 1:42:06.981858
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:32:45.396674
# Low limit
#  Linear GAP prediction: 5:33:20.430000
#  Pete Reigel with a low GAP prediction: 1:32:08.461068
#
# Run log number 104
# Top limit
#  Linear pace prediction: 6:02:52.620000
#  Pete Reigel with a high GAP prediction: 0:34:31.703642
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:30:05.625541
# Low limit
#  Linear GAP prediction: 6:02:52.620000
#  Pete Reigel with a low GAP prediction: 0:29:48.514811
#
# Run log number 105
# Top limit
#  Linear pace prediction: 5:57:15.060000
#  Pete Reigel with a high GAP prediction: 0:27:42.823692
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:26:03.047409
# Low limit
#  Linear GAP prediction: 5:57:15.060000
#  Pete Reigel with a low GAP prediction: 0:25:56.362311
#
# Run log number 106
# Top limit
#  Linear pace prediction: 5:31:56.040000
#  Pete Reigel with a high GAP prediction: 0:25:26.960550
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:23:39.950605
# Low limit
#  Linear GAP prediction: 5:31:56.040000
#  Pete Reigel with a low GAP prediction: 0:23:32.822466
#
# Run log number 107
# Top limit
#  Linear pace prediction: 5:26:18.480000
#  Pete Reigel with a high GAP prediction: 3:48:08.679948
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:31:29.216608
# Low limit
#  Linear GAP prediction: 5:26:18.480000
#  Pete Reigel with a low GAP prediction: 3:30:22.754087
#
# Run log number 108
# Top limit
#  Linear pace prediction: 5:32:38.235000
#  Pete Reigel with a high GAP prediction: 4:18:03.069189
# Middle limit
#  Pete Reigel with a medium GAP prediction: 4:03:12.488918
# Low limit
#  Linear GAP prediction: 5:32:38.235000
#  Pete Reigel with a low GAP prediction: 4:02:12.734202
#
# Run log number 109
# Top limit
#  Linear pace prediction: 5:42:28.965000
#  Pete Reigel with a high GAP prediction: 1:02:44.285578
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:56:55.646988
# Low limit
#  Linear GAP prediction: 5:42:28.965000
#  Pete Reigel with a low GAP prediction: 0:56:32.730086
#
# Run log number 110
# Top limit
#  Linear pace prediction: 5:54:26.280000
#  Pete Reigel with a high GAP prediction: 0:02:34.449154
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:02:25.141042
# Low limit
#  Linear GAP prediction: 5:54:26.280000
#  Pete Reigel with a low GAP prediction: 0:02:24.517485
#
# Run log number 111
# Top limit
#  Linear pace prediction: 5:43:53.355000
#  Pete Reigel with a high GAP prediction: 0:05:46.155304
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:05:13.598850
# Low limit
#  Linear GAP prediction: 5:43:53.355000
#  Pete Reigel with a low GAP prediction: 0:05:11.460668
#
# Run log number 112
# Top limit
#  Linear pace prediction: 5:14:21.165000
#  Pete Reigel with a high GAP prediction: 3:40:43.048176
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:23:06.402409
# Low limit
#  Linear GAP prediction: 5:14:21.165000
#  Pete Reigel with a low GAP prediction: 3:21:56.415762
#
# Run log number 113
# Top limit
#  Linear pace prediction: 5:21:23.115000
#  Pete Reigel with a high GAP prediction: 1:47:25.936347
# Middle limit
#  Pete Reigel with a medium GAP prediction: 1:36:15.495320
# Low limit
#  Linear GAP prediction: 5:21:23.115000
#  Pete Reigel with a low GAP prediction: 1:35:31.726957
#
# Run log number 114
# Top limit
#  Linear pace prediction: 5:57:15.060000
#  Pete Reigel with a high GAP prediction: 0:04:06.000472
# Middle limit
#  Pete Reigel with a medium GAP prediction: 0:03:39.522482
# Low limit
#  Linear GAP prediction: 5:57:15.060000
#  Pete Reigel with a low GAP prediction: 0:03:37.797727
#
# Run log number 115
# Top limit
#  Linear pace prediction: 6:02:10.425000
#  Pete Reigel with a high GAP prediction: 3:14:12.639222
# Middle limit
#  Pete Reigel with a medium GAP prediction: 3:10:51.464054
# Low limit
#  Linear GAP prediction: 6:02:10.425000
#  Pete Reigel with a low GAP prediction: 3:10:37.658860
